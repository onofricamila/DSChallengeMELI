# %% [markdown]
# TODO:
#
#     - separar en carga raw, manipulacion, eda
#     - no hacer ese fill na cuando paso bool a int (astype?)
#     - sacar las listas temporales de cols a elegir y quedarme con cols
#     - checkear el astype int .... tema bools: creo que deberia crear la de oficial store y dejarlas como tipo object

# %%
import json
from urllib.request import urlopen
import urllib
import pandas as pd
from tqdm.notebook import tqdm
import os
import matplotlib.pyplot as plt
import joblib

# %%
os.chdir("..")

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("<style>.prompt { font-size: 08px !important; }</style>"))
pd.options.display.max_columns = None
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.prompt { font-size: 08px !important; }</style>

# %%
data_path = "data/"

# %%
input_path = data_path + 'input/'

# %% [markdown]
# # 1️⃣ Dataload
# ---

# %%
url_base = "https://api.mercadolibre.com/"

# %%
url_MLA = url_base + "/sites/MLA/"

# %%
limit = 50 # fixed

# %%
items_per_category = 1000 # chosen

# %%
requests_per_category = int(items_per_category / limit)
requests_per_category
# Out:
# 20

# %% [markdown]
# ## Fxs

# %%
def get_data(url):
    # makes a get request given a url, and returns json response
    response = urllib.request.urlopen(url)
    return json.load(response)

# %%
def load_category_items(categ_id):
    # gets items given a category id
    url_categ = url_MLA + "search?&category={}".format(categ_id)
    all_results = [] # offset and limit must be taken into account to reach items_per_category
    for r in range(0, requests_per_category):
        offset = r * limit
        url = url_categ + "&offset={}".format(offset)
        response = get_data(url)
        results = response['results'] # keep only the items
        all_results = all_results + results
    return all_results

# %% [markdown]
# ## Get root categories

# %%
url = url_MLA + "categories"

# %%
root_categories = get_data(url)
root_categories
# Out:
# [{'id': 'MLA5725', 'name': 'Accesorios para Vehículos'},
#  {'id': 'MLA1512', 'name': 'Agro'},
#  {'id': 'MLA1403', 'name': 'Alimentos y Bebidas'},
#  {'id': 'MLA1071', 'name': 'Animales y Mascotas'},
#  {'id': 'MLA1367', 'name': 'Antigüedades y Colecciones'},
#  {'id': 'MLA1368', 'name': 'Arte, Librería y Mercería'},
#  {'id': 'MLA1743', 'name': 'Autos, Motos y Otros'},
#  {'id': 'MLA1384', 'name': 'Bebés'},
#  {'id': 'MLA1246', 'name': 'Belleza y Cuidado Personal'},
#  {'id': 'MLA1039', 'name': 'Cámaras y Accesorios'},
#  {'id': 'MLA1051', 'name': 'Celulares y Teléfonos'},
#  {'id': 'MLA1648', 'name': 'Computación'},
#  {'id': 'MLA1144', 'name': 'Consolas y Videojuegos'},
#  {'id': 'MLA1276', 'name': 'Deportes y Fitness'},
#  {'id': 'MLA5726', 'name': 'Electrodomésticos y Aires Ac.'},
#  {'id': 'MLA1000', 'name': 'Electrónica, Audio y Video'},
#  {'id': 'MLA2547', 'name': 'Entradas para Eventos'},
#  {'id': 'MLA407134', 'name': 'Herramientas y Construcción'},
#  {'id': 'MLA1574', 'name': 'Hogar, Muebles y Jardín'},
#  {'id': 'MLA1499', 'name': 'Industrias y Oficinas'},
#  {'id': 'MLA1459', 'name': 'Inmuebles'},
#  {'id': 'MLA1182', 'name': 'Instrumentos Musicales'},
#  {'id': 'MLA3937', 'name': 'Joyas y Relojes'},
#  {'id': 'MLA1132', 'name': 'Juegos y Juguetes'},
#  {'id': 'MLA3025', 'name': 'Libros, Revistas y Comics'},
#  {'id': 'MLA1168', 'name': 'Música, Películas y Series'},
#  {'id': 'MLA1430', 'name': 'Ropa y Accesorios'},
#  {'id': 'MLA409431', 'name': 'Salud y Equipamiento Médico'},
#  {'id': 'MLA1540', 'name': 'Servicios'},
#  {'id': 'MLA9304', 'name': 'Souvenirs, Cotillón y Fiestas'},
#  {'id': 'MLA1953', 'name': 'Otras categorías'}]

# %% [markdown]
# ## Get items per root category

# %%
df = pd.DataFrame() # will contain items from all root categories
for c in tqdm(root_categories):
    all_results = load_category_items(c["id"])
    df_tmp = pd.json_normalize(all_results) # build a pd df from a json with nested data (notice how lists remain lists)
    # add root category data to the df with category items
    df_tmp["root_category_id"] = c["id"]
    df_tmp["root_category_name"] = c["name"]
    # append df_tmp to the final df
    df = df.append(df_tmp, ignore_index=True)
# Out:
#   0%|          | 0/31 [00:00<?, ?it/s]

# %% [markdown]
# **Inspect df**

# %%
df.shape
# Out:
# (30907, 132)

# %%
df.columns.tolist()
# Out:
# ['id',
#  'site_id',
#  'title',
#  'price',
#  'sale_price',
#  'currency_id',
#  'available_quantity',
#  'sold_quantity',
#  'buying_mode',
#  'listing_type_id',
#  'stop_time',
#  'condition',
#  'permalink',
#  'thumbnail',
#  'thumbnail_id',
#  'accepts_mercadopago',
#  'attributes',
#  'original_price',
#  'category_id',
#  'official_store_id',
#  'domain_id',
#  'catalog_product_id',
#  'tags',
#  'catalog_listing',
#  'use_thumbnail_id',
#  'order_backend',
#  'seller.id',
#  'seller.permalink',
#  'seller.registration_date',
#  'seller.car_dealer',
#  'seller.real_estate_agency',
#  'seller.tags',
#  'seller.eshop.nick_name',
#  'seller.eshop.eshop_rubro',
#  'seller.eshop.eshop_id',
#  'seller.eshop.eshop_locations',
#  'seller.eshop.site_id',
#  'seller.eshop.eshop_logo_url',
#  'seller.eshop.eshop_status_id',
#  'seller.eshop.seller',
#  'seller.eshop.eshop_experience',
#  'seller.seller_reputation.transactions.total',
#  'seller.seller_reputation.transactions.canceled',
#  'seller.seller_reputation.transactions.period',
#  'seller.seller_reputation.transactions.ratings.negative',
#  'seller.seller_reputation.transactions.ratings.positive',
#  'seller.seller_reputation.transactions.ratings.neutral',
#  'seller.seller_reputation.transactions.completed',
#  'seller.seller_reputation.power_seller_status',
#  'seller.seller_reputation.metrics.claims.rate',
#  'seller.seller_reputation.metrics.claims.value',
#  'seller.seller_reputation.metrics.claims.period',
#  'seller.seller_reputation.metrics.delayed_handling_time.rate',
#  'seller.seller_reputation.metrics.delayed_handling_time.value',
#  'seller.seller_reputation.metrics.delayed_handling_time.period',
#  'seller.seller_reputation.metrics.sales.period',
#  'seller.seller_reputation.metrics.sales.completed',
#  'seller.seller_reputation.metrics.cancellations.rate',
#  'seller.seller_reputation.metrics.cancellations.value',
#  'seller.seller_reputation.metrics.cancellations.period',
#  'seller.seller_reputation.level_id',
#  'prices.id',
#  'prices.prices',
#  'prices.presentation.display_currency',
#  'prices.payment_method_prices',
#  'installments.quantity',
#  'installments.amount',
#  'installments.rate',
#  'installments.currency_id',
#  'address.state_id',
#  'address.state_name',
#  'address.city_id',
#  'address.city_name',
#  'shipping.free_shipping',
#  'shipping.mode',
#  'shipping.tags',
#  'shipping.logistic_type',
#  'shipping.store_pick_up',
#  'seller_address.id',
#  'seller_address.comment',
#  'seller_address.address_line',
#  'seller_address.zip_code',
#  'seller_address.country.id',
#  'seller_address.country.name',
#  'seller_address.state.id',
#  'seller_address.state.name',
#  'seller_address.city.id',
#  'seller_address.city.name',
#  'seller_address.latitude',
#  'seller_address.longitude',
#  'differential_pricing.id',
#  'seller.seller_reputation.metrics.claims.excluded.real_rate',
#  'seller.seller_reputation.metrics.claims.excluded.real_value',
#  'seller.seller_reputation.metrics.delayed_handling_time.excluded.real_rate',
#  'seller.seller_reputation.metrics.delayed_handling_time.excluded.real_value',
#  'seller.seller_reputation.metrics.cancellations.excluded.real_rate',
#  'seller.seller_reputation.metrics.cancellations.excluded.real_value',
#  'seller.seller_reputation.protection_end_date',
#  'seller.seller_reputation.real_level',
#  'seller.car_dealer_logo',
#  'seller.eshop.eshop_rubro.id',
#  'seller.eshop.eshop_rubro.name',
#  'seller.eshop.eshop_rubro.category_id',
#  'root_category_id',
#  'root_category_name',
#  'prices',
#  'installments',
#  'address.area_code',
#  'address.phone1',
#  'seller_contact.contact',
#  'seller_contact.other_info',
#  'seller_contact.area_code',
#  'seller_contact.phone',
#  'seller_contact.area_code2',
#  'seller_contact.phone2',
#  'seller_contact.email',
#  'seller_contact.webpage',
#  'location.address_line',
#  'location.zip_code',
#  'location.subneighborhood',
#  'location.neighborhood.id',
#  'location.neighborhood.name',
#  'location.city.id',
#  'location.city.name',
#  'location.state.id',
#  'location.state.name',
#  'location.country.id',
#  'location.country.name',
#  'location.latitude',
#  'location.longitude',
#  'seller.home_image_url',
#  'sale_terms']

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['price',
#  'sale_price',
#  'currency_id',
#  'condition',
#  'thumbnail_id',
#  'original_price',
#  'official_store_id',
#  'domain_id',
#  'catalog_product_id',
#  'catalog_listing',
#  'seller.permalink',
#  'seller.registration_date',
#  'seller.tags',
#  'seller.eshop.nick_name',
#  'seller.eshop.eshop_rubro',
#  'seller.eshop.eshop_id',
#  'seller.eshop.eshop_locations',
#  'seller.eshop.site_id',
#  'seller.eshop.eshop_logo_url',
#  'seller.eshop.eshop_status_id',
#  'seller.eshop.seller',
#  'seller.eshop.eshop_experience',
#  'seller.seller_reputation.transactions.total',
#  'seller.seller_reputation.transactions.canceled',
#  'seller.seller_reputation.transactions.period',
#  'seller.seller_reputation.transactions.ratings.negative',
#  'seller.seller_reputation.transactions.ratings.positive',
#  'seller.seller_reputation.transactions.ratings.neutral',
#  'seller.seller_reputation.transactions.completed',
#  'seller.seller_reputation.power_seller_status',
#  'seller.seller_reputation.metrics.claims.rate',
#  'seller.seller_reputation.metrics.claims.value',
#  'seller.seller_reputation.metrics.claims.period',
#  'seller.seller_reputation.metrics.delayed_handling_time.rate',
#  'seller.seller_reputation.metrics.delayed_handling_time.value',
#  'seller.seller_reputation.metrics.delayed_handling_time.period',
#  'seller.seller_reputation.metrics.sales.period',
#  'seller.seller_reputation.metrics.sales.completed',
#  'seller.seller_reputation.metrics.cancellations.rate',
#  'seller.seller_reputation.metrics.cancellations.value',
#  'seller.seller_reputation.metrics.cancellations.period',
#  'seller.seller_reputation.level_id',
#  'prices.id',
#  'prices.prices',
#  'prices.presentation.display_currency',
#  'prices.payment_method_prices',
#  'installments.quantity',
#  'installments.amount',
#  'installments.rate',
#  'installments.currency_id',
#  'address.city_id',
#  'shipping.logistic_type',
#  'seller_address.city.id',
#  'differential_pricing.id',
#  'seller.seller_reputation.metrics.claims.excluded.real_rate',
#  'seller.seller_reputation.metrics.claims.excluded.real_value',
#  'seller.seller_reputation.metrics.delayed_handling_time.excluded.real_rate',
#  'seller.seller_reputation.metrics.delayed_handling_time.excluded.real_value',
#  'seller.seller_reputation.metrics.cancellations.excluded.real_rate',
#  'seller.seller_reputation.metrics.cancellations.excluded.real_value',
#  'seller.seller_reputation.protection_end_date',
#  'seller.seller_reputation.real_level',
#  'seller.car_dealer_logo',
#  'seller.eshop.eshop_rubro.id',
#  'seller.eshop.eshop_rubro.name',
#  'seller.eshop.eshop_rubro.category_id',
#  'prices',
#  'installments',
#  'address.area_code',
#  'address.phone1',
#  'seller_contact.contact',
#  'seller_contact.other_info',
#  'seller_contact.area_code',
#  'seller_contact.phone',
#  'seller_contact.area_code2',
#  'seller_contact.phone2',
#  'seller_contact.email',
#  'seller_contact.webpage',
#  'location.address_line',
#  'location.zip_code',
#  'location.subneighborhood',
#  'location.neighborhood.id',
#  'location.neighborhood.name',
#  'location.city.id',
#  'location.city.name',
#  'location.state.id',
#  'location.state.name',
#  'location.country.id',
#  'location.country.name',
#  'location.latitude',
#  'location.longitude',
#  'seller.home_image_url',
#  'sale_terms']

# %% [markdown]
# Search for specific columns

# %%
[x for x in df.columns if "installments" in x]
# Out:
# ['installments.quantity',
#  'installments.amount',
#  'installments.rate',
#  'installments.currency_id',
#  'installments']

# %%
df['installments.rate'].value_counts()
# Out:
# 70.17    26021
# 0.00      2640
# Name: installments.rate, dtype: int64

# %%
df.category_id[0]
# Out:
# 'MLA6867'

# %% [markdown]
# ## Get subcategories info
# Recursive algorithm

# %%
def get_subcategories_from_root(categ_id, dic):
    # recursive function to get subcategories data 
    url = url_base + "categories/{}".format(categ_id)
    response = get_data(url)
    children_categories = response["children_categories"]
    for cc in children_categories: # base case: children_categories list is empty
        id = cc["id"]
        dic[id] = {"name": cc["name"], 
                    "root": response["path_from_root"]} # 'root' does not include current category as response["path_from_root"] has parent category data 
        get_subcategories_from_root(id, dic)

# %% [markdown]
# **Get subcategories info for all root categories**

# %%
dic_all_categories = {}
for c in tqdm(root_categories):
    dic = {}
    get_subcategories_from_root(c["id"], dic)  
    dic_all_categories.update(dic)
# Out:
#   0%|          | 0/31 [00:00<?, ?it/s]

# %% [markdown]
# **Inspect dic_all_categories**

# %%
len(dic_all_categories)
# Out:
# 9541

# %%
first_key = next(iter(dic_all_categories)) 
first_key
# Out:
# 'MLA4711'

# %%
dic_all_categories[first_key]
# Out:
# {'name': 'Acc. para Motos y Cuatriciclos',
#  'root': [{'id': 'MLA5725', 'name': 'Accesorios para Vehículos'}]}

# %% [markdown]
# **Persist dic_all_categories**

# %%
file_name = input_path + "dic_all_categories.joblib"
joblib.dump(dic_all_categories, file_name)
# Out:
# ['data/input/dic_all_categories.joblib']

# %% [markdown]
# # 2️⃣ Manipulación básica
# ---

# %%
df.head()
# Out:
#              id site_id                                              title  \
# 0  MLA901948080     MLA  Estéreo Para Auto Pioneer Mvh S215bt Con Usb Y...
# 1  MLA869356478     MLA    Neumático Pirelli Formula Energy 185/60 R14 82h
# 2  MLA851109741     MLA  Carcasa Llave Navaja Peugeot  2 Bot 307 308 C/...
# 3  MLA836983125     MLA            Funda Cubre Rueda Auxilio Ford Ecosport
# 4  MLA899116906     MLA  Servicio De Envío Express De Telepase Mercado ...
#
#      price sale_price currency_id  available_quantity  sold_quantity  \
# 0  12600.0       None         ARS                   1             22
# 1  10250.0       None         ARS                  63           1480
# 2    799.0       None         ARS                  50            500
# 3    891.0       None         ARS                 100            250
# 4    655.0       None         ARS                 500           5000
#
#   buying_mode listing_type_id                 stop_time condition  \
# 0  buy_it_now    gold_special  2040-12-17T04:00:00.000Z       new
# 1  buy_it_now    gold_special  2040-07-16T04:00:00.000Z       new
# 2  buy_it_now    gold_special  2040-04-18T04:00:00.000Z       new
# 3  buy_it_now        gold_pro  2040-01-26T04:00:00.000Z       new
# 4  buy_it_now    gold_special  2040-11-22T04:00:00.000Z       new
#
#                                            permalink  \
# 0  https://www.mercadolibre.com.ar/estereo-para-a...
# 1  https://www.mercadolibre.com.ar/neumatico-pire...
# 2  https://articulo.mercadolibre.com.ar/MLA-85110...
# 3  https://articulo.mercadolibre.com.ar/MLA-83698...
# 4  https://articulo.mercadolibre.com.ar/MLA-89911...
#
#                                            thumbnail  \
# 0  http://http2.mlstatic.com/D_960260-MLA33082733...
# 1  http://http2.mlstatic.com/D_677078-MLA40312695...
# 2  http://http2.mlstatic.com/D_712655-MLA31486068...
# 3  http://http2.mlstatic.com/D_627755-MLA40614836...
# 4  http://http2.mlstatic.com/D_998863-MLA44807410...
#
#                    thumbnail_id  accepts_mercadopago  \
# 0  960260-MLA33082733743_122019                 True
# 1  677078-MLA40312695444_012020                 True
# 2  712655-MLA31486068217_072019                 True
# 3  627755-MLA40614836927_012020                 True
# 4  998863-MLA44807410381_022021                 True
#
#                                           attributes original_price  \
# 0  [{'source': 1, 'name': 'Marca del stereo', 'va...            NaN
# 1  [{'value_id': '76026', 'value_name': 'Pirelli'...            NaN
# 2  [{'values': [{'source': 2860837171021627, 'id'...            NaN
# 3  [{'values': [{'id': None, 'name': 'Mego EcoSpo...          990.0
# 4  [{'source': 6808261514773724, 'value_name': 'T...            NaN
#
#   category_id official_store_id                         domain_id  \
# 0     MLA6867               NaN               MLA-VEHICLE_STEREOS
# 1    MLA22195             143.0              MLA-AUTOMOTIVE_TIRES
# 2   MLA373345               NaN      MLA-AUTOMOTIVE_IGNITION_KEYS
# 3   MLA403345               NaN  MLA-AUTOMOTIVE_SPARE_TIRE_COVERS
# 4   MLA455216            2422.0                     MLA-TOLL_TAGS
#
#   catalog_product_id                                               tags  \
# 0        MLA14983192  [brand_verified, extended_warranty_eligible, g...
# 1        MLA15000133  [brand_verified, good_quality_picture, good_qu...
# 2               None  [good_quality_picture, good_quality_thumbnail,...
# 3               None  [brand_verified, good_quality_picture, good_qu...
# 4               None  [brand_verified, good_quality_picture, good_qu...
#
#   catalog_listing  use_thumbnail_id  order_backend  seller.id  \
# 0            True              True              1    8911722
# 1            True              True              2  116026826
# 2             NaN              True              3  435859328
# 3             NaN              True              4   20861971
# 4             NaN              True              5  679055037
#
#                                     seller.permalink  \
# 0      http://perfil.mercadolibre.com.ar/AR+ESCALADA
# 1        http://perfil.mercadolibre.com.ar/NEUMEN-SA
# 2  http://perfil.mercadolibre.com.ar/LACORDIALAUT...
# 3       http://perfil.mercadolibre.com.ar/MEGO+STOCK
# 4         http://perfil.mercadolibre.com.ar/TELEPASE
#
#         seller.registration_date  seller.car_dealer  \
# 0  2011-04-19T14:37:11.000-04:00              False
# 1  2014-08-01T14:48:29.000-04:00              False
# 2  2019-05-14T14:01:06.000-04:00              False
# 3  2003-04-12T00:00:00.000-04:00              False
# 4  2020-11-27T17:57:32.000-04:00              False
#
#    seller.real_estate_agency  \
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
#
#                                          seller.tags seller.eshop.nick_name  \
# 0  [normal, user_info_verified, eshop, credits_pr...            AR ESCALADA
# 1  [brand, user_info_verified, large_seller, esho...              NEUMEN-SA
# 2  [normal, user_info_verified, eshop, mshops, cr...    LACORDIALAUTOPARTES
# 3  [normal, user_info_verified, credits_profile, ...                    NaN
# 4  [brand, user_info_verified, large_seller, cred...                    NaN
#
#    seller.eshop.eshop_rubro  seller.eshop.eshop_id  \
# 0                       NaN               207342.0
# 1                       NaN               220645.0
# 2                       NaN               407559.0
# 3                       NaN                    NaN
# 4                       NaN                    NaN
#
#   seller.eshop.eshop_locations seller.eshop.site_id  \
# 0                           []                  MLA
# 1                           []                  MLA
# 2                           []                  MLA
# 3                          NaN                  NaN
# 4                          NaN                  NaN
#
#                          seller.eshop.eshop_logo_url  \
# 0  http://resources.mlstatic.com/eshops/8911722va...
# 1  http://resources.mlstatic.com/eshops/116026826...
# 2  http://resources.mlstatic.com/eshops/435859328...
# 3                                                NaN
# 4                                                NaN
#
#    seller.eshop.eshop_status_id  seller.eshop.seller  \
# 0                           1.0            8911722.0
# 1                           2.0          116026826.0
# 2                           1.0          435859328.0
# 3                           NaN                  NaN
# 4                           NaN                  NaN
#
#    seller.eshop.eshop_experience  seller.seller_reputation.transactions.total  \
# 0                            0.0                                        415.0
# 1                            0.0                                      22539.0
# 2                            0.0                                       7371.0
# 3                            NaN                                       1036.0
# 4                            NaN                                      25361.0
#
#    seller.seller_reputation.transactions.canceled  \
# 0                                            30.0
# 1                                           975.0
# 2                                           386.0
# 3                                            31.0
# 4                                          1525.0
#
#   seller.seller_reputation.transactions.period  \
# 0                                     historic
# 1                                     historic
# 2                                     historic
# 3                                     historic
# 4                                     historic
#
#    seller.seller_reputation.transactions.ratings.negative  \
# 0                                               0.01
# 1                                               0.01
# 2                                               0.01
# 3                                               0.01
# 4                                               0.03
#
#    seller.seller_reputation.transactions.ratings.positive  \
# 0                                               0.99
# 1                                               0.96
# 2                                               0.98
# 3                                               0.99
# 4                                               0.96
#
#    seller.seller_reputation.transactions.ratings.neutral  \
# 0                                               0.00
# 1                                               0.03
# 2                                               0.01
# 3                                               0.00
# 4                                               0.01
#
#    seller.seller_reputation.transactions.completed  \
# 0                                            385.0
# 1                                          21564.0
# 2                                           6985.0
# 3                                           1005.0
# 4                                          23836.0
#
#   seller.seller_reputation.power_seller_status  \
# 0                                       silver
# 1                                     platinum
# 2                                     platinum
# 3                                         gold
# 4                                         None
#
#    seller.seller_reputation.metrics.claims.rate  \
# 0                                        0.0000
# 1                                        0.0039
# 2                                        0.0058
# 3                                        0.0000
# 4                                        0.0017
#
#    seller.seller_reputation.metrics.claims.value  \
# 0                                            1.0
# 1                                           15.0
# 2                                           14.0
# 3                                            1.0
# 4                                           23.0
#
#   seller.seller_reputation.metrics.claims.period  \
# 0                                        60 days
# 1                                        60 days
# 2                                        60 days
# 3                                        60 days
# 4                                        60 days
#
#    seller.seller_reputation.metrics.delayed_handling_time.rate  \
# 0                                             0.0000
# 1                                             0.0559
# 2                                             0.0033
# 3                                             0.0000
# 4                                             0.0000
#
#    seller.seller_reputation.metrics.delayed_handling_time.value  \
# 0                                                0.0
# 1                                              166.0
# 2                                                8.0
# 3                                                0.0
# 4                                                1.0
#
#   seller.seller_reputation.metrics.delayed_handling_time.period  \
# 0                                            60 days
# 1                                            60 days
# 2                                            60 days
# 3                                            60 days
# 4                                            60 days
#
#   seller.seller_reputation.metrics.sales.period  \
# 0                                       60 days
# 1                                       60 days
# 2                                       60 days
# 3                                       60 days
# 4                                       60 days
#
#    seller.seller_reputation.metrics.sales.completed  \
# 0                                              68.0
# 1                                            3662.0
# 2                                            2313.0
# 3                                             455.0
# 4                                           12476.0
#
#    seller.seller_reputation.metrics.cancellations.rate  \
# 0                                             0.0000
# 1                                             0.0046
# 2                                             0.0000
# 3                                             0.0000
# 4                                             0.0000
#
#    seller.seller_reputation.metrics.cancellations.value  \
# 0                                                0.0
# 1                                               18.0
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#   seller.seller_reputation.metrics.cancellations.period  \
# 0                                            60 days
# 1                                            60 days
# 2                                            60 days
# 3                                            60 days
# 4                                            60 days
#
#   seller.seller_reputation.level_id     prices.id  \
# 0                           5_green  MLA901948080
# 1                           5_green  MLA869356478
# 2                           5_green  MLA851109741
# 3                           5_green  MLA836983125
# 4                           5_green  MLA899116906
#
#                                        prices.prices  \
# 0  [{'id': '19', 'type': 'standard', 'conditions'...
# 1  [{'id': '24', 'type': 'standard', 'conditions'...
# 2  [{'id': '3', 'type': 'standard', 'conditions':...
# 3  [{'id': '3', 'type': 'standard', 'conditions':...
# 4  [{'id': '2', 'type': 'standard', 'conditions':...
#
#   prices.presentation.display_currency prices.payment_method_prices  \
# 0                                  ARS                           []
# 1                                  ARS                           []
# 2                                  ARS                           []
# 3                                  ARS                           []
# 4                                  ARS                           []
#
#    installments.quantity  installments.amount  installments.rate  \
# 0                   12.0              1786.79              70.17
# 1                   12.0              1453.54              70.17
# 2                   12.0               113.30              70.17
# 3                    9.0                99.00               0.00
# 4                   12.0                92.88              70.17
#
#   installments.currency_id address.state_id address.state_name  \
# 0                      ARS             AR-B       Buenos Aires
# 1                      ARS             AR-B       Buenos Aires
# 2                      ARS             AR-S           Santa Fe
# 3                      ARS             AR-C    Capital Federal
# 4                      ARS             AR-C    Capital Federal
#
#     address.city_id     address.city_name  shipping.free_shipping  \
# 0              None  Remedios de Escalada                    True
# 1  TUxBQ0xPTWMwNjk3       Lomas de Zamora                    True
# 2              None              Santa Fe                   False
# 3  TUxBQlZJTDYzNzZa          Villa Devoto                   False
# 4  TUxBQlBBUjUyOTZa      Parque Chacabuco                    True
#
#   shipping.mode                               shipping.tags  \
# 0           me2  [self_service_in, mandatory_free_shipping]
# 1           me2                   [mandatory_free_shipping]
# 2           me2                               [fulfillment]
# 3           me2              [fulfillment, self_service_in]
# 4           me2              [fulfillment, self_service_in]
#
#   shipping.logistic_type  shipping.store_pick_up seller_address.id  \
# 0               drop_off                   False
# 1          cross_docking                    True
# 2            fulfillment                   False
# 3            fulfillment                   False
# 4            fulfillment                   False
#
#   seller_address.comment seller_address.address_line seller_address.zip_code  \
# 0
# 1
# 2
# 3
# 4
#
#   seller_address.country.id seller_address.country.name  \
# 0                        AR                   Argentina
# 1                        AR                   Argentina
# 2                        AR                   Argentina
# 3                        AR                   Argentina
# 4                        AR                   Argentina
#
#   seller_address.state.id seller_address.state.name seller_address.city.id  \
# 0                    AR-B              Buenos Aires                   None
# 1                    AR-B              Buenos Aires       TUxBQ0xPTWMwNjk3
# 2                    AR-S                  Santa Fe                   None
# 3                    AR-C           Capital Federal       TUxBQlZJTDYzNzZa
# 4                    AR-C           Capital Federal       TUxBQlBBUjUyOTZa
#
#   seller_address.city.name seller_address.latitude seller_address.longitude  \
# 0     Remedios de Escalada
# 1          Lomas de Zamora
# 2                 Santa Fe
# 3             Villa Devoto
# 4         Parque Chacabuco
#
#    differential_pricing.id  \
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3               33678187.0
# 4                      NaN
#
#    seller.seller_reputation.metrics.claims.excluded.real_rate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    seller.seller_reputation.metrics.claims.excluded.real_value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    seller.seller_reputation.metrics.delayed_handling_time.excluded.real_rate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    seller.seller_reputation.metrics.delayed_handling_time.excluded.real_value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    seller.seller_reputation.metrics.cancellations.excluded.real_rate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    seller.seller_reputation.metrics.cancellations.excluded.real_value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   seller.seller_reputation.protection_end_date  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   seller.seller_reputation.real_level seller.car_dealer_logo  \
# 0                                 NaN                    NaN
# 1                                 NaN                    NaN
# 2                                 NaN                    NaN
# 3                                 NaN                    NaN
# 4                                 NaN                    NaN
#
#   seller.eshop.eshop_rubro.id seller.eshop.eshop_rubro.name  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   seller.eshop.eshop_rubro.category_id root_category_id  \
# 0                                  NaN          MLA5725
# 1                                  NaN          MLA5725
# 2                                  NaN          MLA5725
# 3                                  NaN          MLA5725
# 4                                  NaN          MLA5725
#
#           root_category_name  prices installments address.area_code  \
# 0  Accesorios para Vehículos     NaN          NaN               NaN
# 1  Accesorios para Vehículos     NaN          NaN               NaN
# 2  Accesorios para Vehículos     NaN          NaN               NaN
# 3  Accesorios para Vehículos     NaN          NaN               NaN
# 4  Accesorios para Vehículos     NaN          NaN               NaN
#
#   address.phone1 seller_contact.contact seller_contact.other_info  \
# 0            NaN                    NaN                       NaN
# 1            NaN                    NaN                       NaN
# 2            NaN                    NaN                       NaN
# 3            NaN                    NaN                       NaN
# 4            NaN                    NaN                       NaN
#
#   seller_contact.area_code seller_contact.phone seller_contact.area_code2  \
# 0                      NaN                  NaN                       NaN
# 1                      NaN                  NaN                       NaN
# 2                      NaN                  NaN                       NaN
# 3                      NaN                  NaN                       NaN
# 4                      NaN                  NaN                       NaN
#
#   seller_contact.phone2 seller_contact.email seller_contact.webpage  \
# 0                   NaN                  NaN                    NaN
# 1                   NaN                  NaN                    NaN
# 2                   NaN                  NaN                    NaN
# 3                   NaN                  NaN                    NaN
# 4                   NaN                  NaN                    NaN
#
#   location.address_line location.zip_code location.subneighborhood  \
# 0                   NaN               NaN                      NaN
# 1                   NaN               NaN                      NaN
# 2                   NaN               NaN                      NaN
# 3                   NaN               NaN                      NaN
# 4                   NaN               NaN                      NaN
#
#   location.neighborhood.id location.neighborhood.name location.city.id  \
# 0                      NaN                        NaN              NaN
# 1                      NaN                        NaN              NaN
# 2                      NaN                        NaN              NaN
# 3                      NaN                        NaN              NaN
# 4                      NaN                        NaN              NaN
#
#   location.city.name location.state.id location.state.name  \
# 0                NaN               NaN                 NaN
# 1                NaN               NaN                 NaN
# 2                NaN               NaN                 NaN
# 3                NaN               NaN                 NaN
# 4                NaN               NaN                 NaN
#
#   location.country.id location.country.name  location.latitude  \
# 0                 NaN                   NaN                NaN
# 1                 NaN                   NaN                NaN
# 2                 NaN                   NaN                NaN
# 3                 NaN                   NaN                NaN
# 4                 NaN                   NaN                NaN
#
#    location.longitude seller.home_image_url sale_terms
# 0                 NaN                   NaN        NaN
# 1                 NaN                   NaN        NaN
# 2                 NaN                   NaN        NaN
# 3                 NaN                   NaN        NaN
# 4                 NaN                   NaN        NaN

# %% [markdown]
# ## Add columns

# %% [markdown]
# **Add discount column**

# %%
df["discount"] = 1 - df.price / df.original_price if df.original_price is not None else None

# %%
df.head()
# Out:
#              id site_id                                              title  \
# 0  MLA901948080     MLA  Estéreo Para Auto Pioneer Mvh S215bt Con Usb Y...
# 1  MLA869356478     MLA    Neumático Pirelli Formula Energy 185/60 R14 82h
# 2  MLA851109741     MLA  Carcasa Llave Navaja Peugeot  2 Bot 307 308 C/...
# 3  MLA836983125     MLA            Funda Cubre Rueda Auxilio Ford Ecosport
# 4  MLA899116906     MLA  Servicio De Envío Express De Telepase Mercado ...
#
#      price sale_price currency_id  available_quantity  sold_quantity  \
# 0  12600.0       None         ARS                   1             22
# 1  10250.0       None         ARS                  63           1480
# 2    799.0       None         ARS                  50            500
# 3    891.0       None         ARS                 100            250
# 4    655.0       None         ARS                 500           5000
#
#   buying_mode listing_type_id                 stop_time condition  \
# 0  buy_it_now    gold_special  2040-12-17T04:00:00.000Z       new
# 1  buy_it_now    gold_special  2040-07-16T04:00:00.000Z       new
# 2  buy_it_now    gold_special  2040-04-18T04:00:00.000Z       new
# 3  buy_it_now        gold_pro  2040-01-26T04:00:00.000Z       new
# 4  buy_it_now    gold_special  2040-11-22T04:00:00.000Z       new
#
#                                            permalink  \
# 0  https://www.mercadolibre.com.ar/estereo-para-a...
# 1  https://www.mercadolibre.com.ar/neumatico-pire...
# 2  https://articulo.mercadolibre.com.ar/MLA-85110...
# 3  https://articulo.mercadolibre.com.ar/MLA-83698...
# 4  https://articulo.mercadolibre.com.ar/MLA-89911...
#
#                                            thumbnail  \
# 0  http://http2.mlstatic.com/D_960260-MLA33082733...
# 1  http://http2.mlstatic.com/D_677078-MLA40312695...
# 2  http://http2.mlstatic.com/D_712655-MLA31486068...
# 3  http://http2.mlstatic.com/D_627755-MLA40614836...
# 4  http://http2.mlstatic.com/D_998863-MLA44807410...
#
#                    thumbnail_id  accepts_mercadopago  \
# 0  960260-MLA33082733743_122019                 True
# 1  677078-MLA40312695444_012020                 True
# 2  712655-MLA31486068217_072019                 True
# 3  627755-MLA40614836927_012020                 True
# 4  998863-MLA44807410381_022021                 True
#
#                                           attributes original_price  \
# 0  [{'source': 1, 'name': 'Marca del stereo', 'va...            NaN
# 1  [{'value_id': '76026', 'value_name': 'Pirelli'...            NaN
# 2  [{'values': [{'source': 2860837171021627, 'id'...            NaN
# 3  [{'values': [{'id': None, 'name': 'Mego EcoSpo...          990.0
# 4  [{'source': 6808261514773724, 'value_name': 'T...            NaN
#
#   category_id official_store_id                         domain_id  \
# 0     MLA6867               NaN               MLA-VEHICLE_STEREOS
# 1    MLA22195             143.0              MLA-AUTOMOTIVE_TIRES
# 2   MLA373345               NaN      MLA-AUTOMOTIVE_IGNITION_KEYS
# 3   MLA403345               NaN  MLA-AUTOMOTIVE_SPARE_TIRE_COVERS
# 4   MLA455216            2422.0                     MLA-TOLL_TAGS
#
#   catalog_product_id                                               tags  \
# 0        MLA14983192  [brand_verified, extended_warranty_eligible, g...
# 1        MLA15000133  [brand_verified, good_quality_picture, good_qu...
# 2               None  [good_quality_picture, good_quality_thumbnail,...
# 3               None  [brand_verified, good_quality_picture, good_qu...
# 4               None  [brand_verified, good_quality_picture, good_qu...
#
#   catalog_listing  use_thumbnail_id  order_backend  seller.id  \
# 0            True              True              1    8911722
# 1            True              True              2  116026826
# 2             NaN              True              3  435859328
# 3             NaN              True              4   20861971
# 4             NaN              True              5  679055037
#
#                                     seller.permalink  \
# 0      http://perfil.mercadolibre.com.ar/AR+ESCALADA
# 1        http://perfil.mercadolibre.com.ar/NEUMEN-SA
# 2  http://perfil.mercadolibre.com.ar/LACORDIALAUT...
# 3       http://perfil.mercadolibre.com.ar/MEGO+STOCK
# 4         http://perfil.mercadolibre.com.ar/TELEPASE
#
#         seller.registration_date  seller.car_dealer  \
# 0  2011-04-19T14:37:11.000-04:00              False
# 1  2014-08-01T14:48:29.000-04:00              False
# 2  2019-05-14T14:01:06.000-04:00              False
# 3  2003-04-12T00:00:00.000-04:00              False
# 4  2020-11-27T17:57:32.000-04:00              False
#
#    seller.real_estate_agency  \
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
#
#                                          seller.tags seller.eshop.nick_name  \
# 0  [normal, user_info_verified, eshop, credits_pr...            AR ESCALADA
# 1  [brand, user_info_verified, large_seller, esho...              NEUMEN-SA
# 2  [normal, user_info_verified, eshop, mshops, cr...    LACORDIALAUTOPARTES
# 3  [normal, user_info_verified, credits_profile, ...                    NaN
# 4  [brand, user_info_verified, large_seller, cred...                    NaN
#
#    seller.eshop.eshop_rubro  seller.eshop.eshop_id  \
# 0                       NaN               207342.0
# 1                       NaN               220645.0
# 2                       NaN               407559.0
# 3                       NaN                    NaN
# 4                       NaN                    NaN
#
#   seller.eshop.eshop_locations seller.eshop.site_id  \
# 0                           []                  MLA
# 1                           []                  MLA
# 2                           []                  MLA
# 3                          NaN                  NaN
# 4                          NaN                  NaN
#
#                          seller.eshop.eshop_logo_url  \
# 0  http://resources.mlstatic.com/eshops/8911722va...
# 1  http://resources.mlstatic.com/eshops/116026826...
# 2  http://resources.mlstatic.com/eshops/435859328...
# 3                                                NaN
# 4                                                NaN
#
#    seller.eshop.eshop_status_id  seller.eshop.seller  \
# 0                           1.0            8911722.0
# 1                           2.0          116026826.0
# 2                           1.0          435859328.0
# 3                           NaN                  NaN
# 4                           NaN                  NaN
#
#    seller.eshop.eshop_experience  seller.seller_reputation.transactions.total  \
# 0                            0.0                                        415.0
# 1                            0.0                                      22539.0
# 2                            0.0                                       7371.0
# 3                            NaN                                       1036.0
# 4                            NaN                                      25361.0
#
#    seller.seller_reputation.transactions.canceled  \
# 0                                            30.0
# 1                                           975.0
# 2                                           386.0
# 3                                            31.0
# 4                                          1525.0
#
#   seller.seller_reputation.transactions.period  \
# 0                                     historic
# 1                                     historic
# 2                                     historic
# 3                                     historic
# 4                                     historic
#
#    seller.seller_reputation.transactions.ratings.negative  \
# 0                                               0.01
# 1                                               0.01
# 2                                               0.01
# 3                                               0.01
# 4                                               0.03
#
#    seller.seller_reputation.transactions.ratings.positive  \
# 0                                               0.99
# 1                                               0.96
# 2                                               0.98
# 3                                               0.99
# 4                                               0.96
#
#    seller.seller_reputation.transactions.ratings.neutral  \
# 0                                               0.00
# 1                                               0.03
# 2                                               0.01
# 3                                               0.00
# 4                                               0.01
#
#    seller.seller_reputation.transactions.completed  \
# 0                                            385.0
# 1                                          21564.0
# 2                                           6985.0
# 3                                           1005.0
# 4                                          23836.0
#
#   seller.seller_reputation.power_seller_status  \
# 0                                       silver
# 1                                     platinum
# 2                                     platinum
# 3                                         gold
# 4                                         None
#
#    seller.seller_reputation.metrics.claims.rate  \
# 0                                        0.0000
# 1                                        0.0039
# 2                                        0.0058
# 3                                        0.0000
# 4                                        0.0017
#
#    seller.seller_reputation.metrics.claims.value  \
# 0                                            1.0
# 1                                           15.0
# 2                                           14.0
# 3                                            1.0
# 4                                           23.0
#
#   seller.seller_reputation.metrics.claims.period  \
# 0                                        60 days
# 1                                        60 days
# 2                                        60 days
# 3                                        60 days
# 4                                        60 days
#
#    seller.seller_reputation.metrics.delayed_handling_time.rate  \
# 0                                             0.0000
# 1                                             0.0559
# 2                                             0.0033
# 3                                             0.0000
# 4                                             0.0000
#
#    seller.seller_reputation.metrics.delayed_handling_time.value  \
# 0                                                0.0
# 1                                              166.0
# 2                                                8.0
# 3                                                0.0
# 4                                                1.0
#
#   seller.seller_reputation.metrics.delayed_handling_time.period  \
# 0                                            60 days
# 1                                            60 days
# 2                                            60 days
# 3                                            60 days
# 4                                            60 days
#
#   seller.seller_reputation.metrics.sales.period  \
# 0                                       60 days
# 1                                       60 days
# 2                                       60 days
# 3                                       60 days
# 4                                       60 days
#
#    seller.seller_reputation.metrics.sales.completed  \
# 0                                              68.0
# 1                                            3662.0
# 2                                            2313.0
# 3                                             455.0
# 4                                           12476.0
#
#    seller.seller_reputation.metrics.cancellations.rate  \
# 0                                             0.0000
# 1                                             0.0046
# 2                                             0.0000
# 3                                             0.0000
# 4                                             0.0000
#
#    seller.seller_reputation.metrics.cancellations.value  \
# 0                                                0.0
# 1                                               18.0
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#   seller.seller_reputation.metrics.cancellations.period  \
# 0                                            60 days
# 1                                            60 days
# 2                                            60 days
# 3                                            60 days
# 4                                            60 days
#
#   seller.seller_reputation.level_id     prices.id  \
# 0                           5_green  MLA901948080
# 1                           5_green  MLA869356478
# 2                           5_green  MLA851109741
# 3                           5_green  MLA836983125
# 4                           5_green  MLA899116906
#
#                                        prices.prices  \
# 0  [{'id': '19', 'type': 'standard', 'conditions'...
# 1  [{'id': '24', 'type': 'standard', 'conditions'...
# 2  [{'id': '3', 'type': 'standard', 'conditions':...
# 3  [{'id': '3', 'type': 'standard', 'conditions':...
# 4  [{'id': '2', 'type': 'standard', 'conditions':...
#
#   prices.presentation.display_currency prices.payment_method_prices  \
# 0                                  ARS                           []
# 1                                  ARS                           []
# 2                                  ARS                           []
# 3                                  ARS                           []
# 4                                  ARS                           []
#
#    installments.quantity  installments.amount  installments.rate  \
# 0                   12.0              1786.79              70.17
# 1                   12.0              1453.54              70.17
# 2                   12.0               113.30              70.17
# 3                    9.0                99.00               0.00
# 4                   12.0                92.88              70.17
#
#   installments.currency_id address.state_id address.state_name  \
# 0                      ARS             AR-B       Buenos Aires
# 1                      ARS             AR-B       Buenos Aires
# 2                      ARS             AR-S           Santa Fe
# 3                      ARS             AR-C    Capital Federal
# 4                      ARS             AR-C    Capital Federal
#
#     address.city_id     address.city_name  shipping.free_shipping  \
# 0              None  Remedios de Escalada                    True
# 1  TUxBQ0xPTWMwNjk3       Lomas de Zamora                    True
# 2              None              Santa Fe                   False
# 3  TUxBQlZJTDYzNzZa          Villa Devoto                   False
# 4  TUxBQlBBUjUyOTZa      Parque Chacabuco                    True
#
#   shipping.mode                               shipping.tags  \
# 0           me2  [self_service_in, mandatory_free_shipping]
# 1           me2                   [mandatory_free_shipping]
# 2           me2                               [fulfillment]
# 3           me2              [fulfillment, self_service_in]
# 4           me2              [fulfillment, self_service_in]
#
#   shipping.logistic_type  shipping.store_pick_up seller_address.id  \
# 0               drop_off                   False
# 1          cross_docking                    True
# 2            fulfillment                   False
# 3            fulfillment                   False
# 4            fulfillment                   False
#
#   seller_address.comment seller_address.address_line seller_address.zip_code  \
# 0
# 1
# 2
# 3
# 4
#
#   seller_address.country.id seller_address.country.name  \
# 0                        AR                   Argentina
# 1                        AR                   Argentina
# 2                        AR                   Argentina
# 3                        AR                   Argentina
# 4                        AR                   Argentina
#
#   seller_address.state.id seller_address.state.name seller_address.city.id  \
# 0                    AR-B              Buenos Aires                   None
# 1                    AR-B              Buenos Aires       TUxBQ0xPTWMwNjk3
# 2                    AR-S                  Santa Fe                   None
# 3                    AR-C           Capital Federal       TUxBQlZJTDYzNzZa
# 4                    AR-C           Capital Federal       TUxBQlBBUjUyOTZa
#
#   seller_address.city.name seller_address.latitude seller_address.longitude  \
# 0     Remedios de Escalada
# 1          Lomas de Zamora
# 2                 Santa Fe
# 3             Villa Devoto
# 4         Parque Chacabuco
#
#    differential_pricing.id  \
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3               33678187.0
# 4                      NaN
#
#    seller.seller_reputation.metrics.claims.excluded.real_rate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    seller.seller_reputation.metrics.claims.excluded.real_value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    seller.seller_reputation.metrics.delayed_handling_time.excluded.real_rate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    seller.seller_reputation.metrics.delayed_handling_time.excluded.real_value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    seller.seller_reputation.metrics.cancellations.excluded.real_rate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    seller.seller_reputation.metrics.cancellations.excluded.real_value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   seller.seller_reputation.protection_end_date  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   seller.seller_reputation.real_level seller.car_dealer_logo  \
# 0                                 NaN                    NaN
# 1                                 NaN                    NaN
# 2                                 NaN                    NaN
# 3                                 NaN                    NaN
# 4                                 NaN                    NaN
#
#   seller.eshop.eshop_rubro.id seller.eshop.eshop_rubro.name  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   seller.eshop.eshop_rubro.category_id root_category_id  \
# 0                                  NaN          MLA5725
# 1                                  NaN          MLA5725
# 2                                  NaN          MLA5725
# 3                                  NaN          MLA5725
# 4                                  NaN          MLA5725
#
#           root_category_name  prices installments address.area_code  \
# 0  Accesorios para Vehículos     NaN          NaN               NaN
# 1  Accesorios para Vehículos     NaN          NaN               NaN
# 2  Accesorios para Vehículos     NaN          NaN               NaN
# 3  Accesorios para Vehículos     NaN          NaN               NaN
# 4  Accesorios para Vehículos     NaN          NaN               NaN
#
#   address.phone1 seller_contact.contact seller_contact.other_info  \
# 0            NaN                    NaN                       NaN
# 1            NaN                    NaN                       NaN
# 2            NaN                    NaN                       NaN
# 3            NaN                    NaN                       NaN
# 4            NaN                    NaN                       NaN
#
#   seller_contact.area_code seller_contact.phone seller_contact.area_code2  \
# 0                      NaN                  NaN                       NaN
# 1                      NaN                  NaN                       NaN
# 2                      NaN                  NaN                       NaN
# 3                      NaN                  NaN                       NaN
# 4                      NaN                  NaN                       NaN
#
#   seller_contact.phone2 seller_contact.email seller_contact.webpage  \
# 0                   NaN                  NaN                    NaN
# 1                   NaN                  NaN                    NaN
# 2                   NaN                  NaN                    NaN
# 3                   NaN                  NaN                    NaN
# 4                   NaN                  NaN                    NaN
#
#   location.address_line location.zip_code location.subneighborhood  \
# 0                   NaN               NaN                      NaN
# 1                   NaN               NaN                      NaN
# 2                   NaN               NaN                      NaN
# 3                   NaN               NaN                      NaN
# 4                   NaN               NaN                      NaN
#
#   location.neighborhood.id location.neighborhood.name location.city.id  \
# 0                      NaN                        NaN              NaN
# 1                      NaN                        NaN              NaN
# 2                      NaN                        NaN              NaN
# 3                      NaN                        NaN              NaN
# 4                      NaN                        NaN              NaN
#
#   location.city.name location.state.id location.state.name  \
# 0                NaN               NaN                 NaN
# 1                NaN               NaN                 NaN
# 2                NaN               NaN                 NaN
# 3                NaN               NaN                 NaN
# 4                NaN               NaN                 NaN
#
#   location.country.id location.country.name  location.latitude  \
# 0                 NaN                   NaN                NaN
# 1                 NaN                   NaN                NaN
# 2                 NaN                   NaN                NaN
# 3                 NaN                   NaN                NaN
# 4                 NaN                   NaN                NaN
#
#    location.longitude seller.home_image_url sale_terms discount
# 0                 NaN                   NaN        NaN      NaN
# 1                 NaN                   NaN        NaN      NaN
# 2                 NaN                   NaN        NaN      NaN
# 3                 NaN                   NaN        NaN      0.1
# 4                 NaN                   NaN        NaN      NaN

# %% [markdown]
# Inspect discount coulumn

# %%
df[~df.original_price.isna()][["id", "site_id", "title", "price", "sale_price", "original_price", "discount"]]
# Out:
#                  id site_id  \
# 3      MLA836983125     MLA
# 7      MLA835929721     MLA
# 13     MLA836882881     MLA
# 14     MLA785918507     MLA
# 16     MLA836881964     MLA
# ...             ...     ...
# 30871  MLA905514102     MLA
# 30873  MLA875687395     MLA
# 30882  MLA868232362     MLA
# 30885  MLA846077762     MLA
# 30896  MLA902021310     MLA
#
#                                                    title    price sale_price  \
# 3                Funda Cubre Rueda Auxilio Ford Ecosport   891.00       None
# 7      Soporte Respaldo Apoyo Lumbar Masajeador Asien...   700.00       None
# 13     Mini Compresor De Aire Portatil 12v 250 Psi Kl...  1003.00       None
# 14     Kit Led Cree Cob H1 H7 H3 9005 12/24v 2019 C6+...   999.00       None
# 16     Compresor De Aire Alto Impacto Portátil 250 Ps...  1599.00       None
# ...                                                  ...      ...        ...
# 30871           Rack Mineria Rig Minero 6 Gpus Aluminio   7599.05       None
# 30873  Bandeja Lion Rolling Circus 27x16 Cm Salamanca...   939.06       None
# 30882  Pack X 4 Sahumerios Naturales Copal, Incienso,...   949.05       None
# 30885  Lote De 40 Escallas En Piedras Semipreciosas A...   722.00       None
# 30896  Carbón Bombita Citronella-naranja Sagrada Madr...   355.11       None
#
#       original_price  discount
# 3              990.0       0.1
# 7             1250.0      0.44
# 13            1249.0  0.196958
# 14            1600.0  0.375625
# 16            1909.0  0.162389
# ...              ...       ...
# 30871         7999.0      0.05
# 30873          999.0      0.06
# 30882          999.0      0.05
# 30885          760.0      0.05
# 30896          399.0      0.11
#
# [3782 rows x 7 columns]

# %% [markdown]
# **Add category name (specific one for each item)**

# %%
df["category_name"] = df.category_id.apply( lambda x: dic_all_categories[x]["name"] if x in dic_all_categories.keys() else None )

# %%
def build_categories_from_root(lis):
    res = []
    for x in lis: 
        res.append(x["name"])
    return res

# %%
df["categories_from_root"] = df.category_id.apply( lambda x: build_categories_from_root(dic_all_categories[x]["root"]) + [df.category_name] if x in dic_all_categories.keys() else None )

# %%
df.head()
# Out:
#              id site_id                                              title  \
# 0  MLA901948080     MLA  Estéreo Para Auto Pioneer Mvh S215bt Con Usb Y...
# 1  MLA869356478     MLA    Neumático Pirelli Formula Energy 185/60 R14 82h
# 2  MLA851109741     MLA  Carcasa Llave Navaja Peugeot  2 Bot 307 308 C/...
# 3  MLA836983125     MLA            Funda Cubre Rueda Auxilio Ford Ecosport
# 4  MLA899116906     MLA  Servicio De Envío Express De Telepase Mercado ...
#
#      price sale_price currency_id  available_quantity  sold_quantity  \
# 0  12600.0       None         ARS                   1             22
# 1  10250.0       None         ARS                  63           1480
# 2    799.0       None         ARS                  50            500
# 3    891.0       None         ARS                 100            250
# 4    655.0       None         ARS                 500           5000
#
#   buying_mode listing_type_id                 stop_time condition  \
# 0  buy_it_now    gold_special  2040-12-17T04:00:00.000Z       new
# 1  buy_it_now    gold_special  2040-07-16T04:00:00.000Z       new
# 2  buy_it_now    gold_special  2040-04-18T04:00:00.000Z       new
# 3  buy_it_now        gold_pro  2040-01-26T04:00:00.000Z       new
# 4  buy_it_now    gold_special  2040-11-22T04:00:00.000Z       new
#
#                                            permalink  \
# 0  https://www.mercadolibre.com.ar/estereo-para-a...
# 1  https://www.mercadolibre.com.ar/neumatico-pire...
# 2  https://articulo.mercadolibre.com.ar/MLA-85110...
# 3  https://articulo.mercadolibre.com.ar/MLA-83698...
# 4  https://articulo.mercadolibre.com.ar/MLA-89911...
#
#                                            thumbnail  \
# 0  http://http2.mlstatic.com/D_960260-MLA33082733...
# 1  http://http2.mlstatic.com/D_677078-MLA40312695...
# 2  http://http2.mlstatic.com/D_712655-MLA31486068...
# 3  http://http2.mlstatic.com/D_627755-MLA40614836...
# 4  http://http2.mlstatic.com/D_998863-MLA44807410...
#
#                    thumbnail_id  accepts_mercadopago  \
# 0  960260-MLA33082733743_122019                 True
# 1  677078-MLA40312695444_012020                 True
# 2  712655-MLA31486068217_072019                 True
# 3  627755-MLA40614836927_012020                 True
# 4  998863-MLA44807410381_022021                 True
#
#                                           attributes original_price  \
# 0  [{'source': 1, 'name': 'Marca del stereo', 'va...            NaN
# 1  [{'value_id': '76026', 'value_name': 'Pirelli'...            NaN
# 2  [{'values': [{'source': 2860837171021627, 'id'...            NaN
# 3  [{'values': [{'id': None, 'name': 'Mego EcoSpo...          990.0
# 4  [{'source': 6808261514773724, 'value_name': 'T...            NaN
#
#   category_id official_store_id                         domain_id  \
# 0     MLA6867               NaN               MLA-VEHICLE_STEREOS
# 1    MLA22195             143.0              MLA-AUTOMOTIVE_TIRES
# 2   MLA373345               NaN      MLA-AUTOMOTIVE_IGNITION_KEYS
# 3   MLA403345               NaN  MLA-AUTOMOTIVE_SPARE_TIRE_COVERS
# 4   MLA455216            2422.0                     MLA-TOLL_TAGS
#
#   catalog_product_id                                               tags  \
# 0        MLA14983192  [brand_verified, extended_warranty_eligible, g...
# 1        MLA15000133  [brand_verified, good_quality_picture, good_qu...
# 2               None  [good_quality_picture, good_quality_thumbnail,...
# 3               None  [brand_verified, good_quality_picture, good_qu...
# 4               None  [brand_verified, good_quality_picture, good_qu...
#
#   catalog_listing  use_thumbnail_id  order_backend  seller.id  \
# 0            True              True              1    8911722
# 1            True              True              2  116026826
# 2             NaN              True              3  435859328
# 3             NaN              True              4   20861971
# 4             NaN              True              5  679055037
#
#                                     seller.permalink  \
# 0      http://perfil.mercadolibre.com.ar/AR+ESCALADA
# 1        http://perfil.mercadolibre.com.ar/NEUMEN-SA
# 2  http://perfil.mercadolibre.com.ar/LACORDIALAUT...
# 3       http://perfil.mercadolibre.com.ar/MEGO+STOCK
# 4         http://perfil.mercadolibre.com.ar/TELEPASE
#
#         seller.registration_date  seller.car_dealer  \
# 0  2011-04-19T14:37:11.000-04:00              False
# 1  2014-08-01T14:48:29.000-04:00              False
# 2  2019-05-14T14:01:06.000-04:00              False
# 3  2003-04-12T00:00:00.000-04:00              False
# 4  2020-11-27T17:57:32.000-04:00              False
#
#    seller.real_estate_agency  \
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
#
#                                          seller.tags seller.eshop.nick_name  \
# 0  [normal, user_info_verified, eshop, credits_pr...            AR ESCALADA
# 1  [brand, user_info_verified, large_seller, esho...              NEUMEN-SA
# 2  [normal, user_info_verified, eshop, mshops, cr...    LACORDIALAUTOPARTES
# 3  [normal, user_info_verified, credits_profile, ...                    NaN
# 4  [brand, user_info_verified, large_seller, cred...                    NaN
#
#    seller.eshop.eshop_rubro  seller.eshop.eshop_id  \
# 0                       NaN               207342.0
# 1                       NaN               220645.0
# 2                       NaN               407559.0
# 3                       NaN                    NaN
# 4                       NaN                    NaN
#
#   seller.eshop.eshop_locations seller.eshop.site_id  \
# 0                           []                  MLA
# 1                           []                  MLA
# 2                           []                  MLA
# 3                          NaN                  NaN
# 4                          NaN                  NaN
#
#                          seller.eshop.eshop_logo_url  \
# 0  http://resources.mlstatic.com/eshops/8911722va...
# 1  http://resources.mlstatic.com/eshops/116026826...
# 2  http://resources.mlstatic.com/eshops/435859328...
# 3                                                NaN
# 4                                                NaN
#
#    seller.eshop.eshop_status_id  seller.eshop.seller  \
# 0                           1.0            8911722.0
# 1                           2.0          116026826.0
# 2                           1.0          435859328.0
# 3                           NaN                  NaN
# 4                           NaN                  NaN
#
#    seller.eshop.eshop_experience  seller.seller_reputation.transactions.total  \
# 0                            0.0                                        415.0
# 1                            0.0                                      22539.0
# 2                            0.0                                       7371.0
# 3                            NaN                                       1036.0
# 4                            NaN                                      25361.0
#
#    seller.seller_reputation.transactions.canceled  \
# 0                                            30.0
# 1                                           975.0
# 2                                           386.0
# 3                                            31.0
# 4                                          1525.0
#
#   seller.seller_reputation.transactions.period  \
# 0                                     historic
# 1                                     historic
# 2                                     historic
# 3                                     historic
# 4                                     historic
#
#    seller.seller_reputation.transactions.ratings.negative  \
# 0                                               0.01
# 1                                               0.01
# 2                                               0.01
# 3                                               0.01
# 4                                               0.03
#
#    seller.seller_reputation.transactions.ratings.positive  \
# 0                                               0.99
# 1                                               0.96
# 2                                               0.98
# 3                                               0.99
# 4                                               0.96
#
#    seller.seller_reputation.transactions.ratings.neutral  \
# 0                                               0.00
# 1                                               0.03
# 2                                               0.01
# 3                                               0.00
# 4                                               0.01
#
#    seller.seller_reputation.transactions.completed  \
# 0                                            385.0
# 1                                          21564.0
# 2                                           6985.0
# 3                                           1005.0
# 4                                          23836.0
#
#   seller.seller_reputation.power_seller_status  \
# 0                                       silver
# 1                                     platinum
# 2                                     platinum
# 3                                         gold
# 4                                         None
#
#    seller.seller_reputation.metrics.claims.rate  \
# 0                                        0.0000
# 1                                        0.0039
# 2                                        0.0058
# 3                                        0.0000
# 4                                        0.0017
#
#    seller.seller_reputation.metrics.claims.value  \
# 0                                            1.0
# 1                                           15.0
# 2                                           14.0
# 3                                            1.0
# 4                                           23.0
#
#   seller.seller_reputation.metrics.claims.period  \
# 0                                        60 days
# 1                                        60 days
# 2                                        60 days
# 3                                        60 days
# 4                                        60 days
#
#    seller.seller_reputation.metrics.delayed_handling_time.rate  \
# 0                                             0.0000
# 1                                             0.0559
# 2                                             0.0033
# 3                                             0.0000
# 4                                             0.0000
#
#    seller.seller_reputation.metrics.delayed_handling_time.value  \
# 0                                                0.0
# 1                                              166.0
# 2                                                8.0
# 3                                                0.0
# 4                                                1.0
#
#   seller.seller_reputation.metrics.delayed_handling_time.period  \
# 0                                            60 days
# 1                                            60 days
# 2                                            60 days
# 3                                            60 days
# 4                                            60 days
#
#   seller.seller_reputation.metrics.sales.period  \
# 0                                       60 days
# 1                                       60 days
# 2                                       60 days
# 3                                       60 days
# 4                                       60 days
#
#    seller.seller_reputation.metrics.sales.completed  \
# 0                                              68.0
# 1                                            3662.0
# 2                                            2313.0
# 3                                             455.0
# 4                                           12476.0
#
#    seller.seller_reputation.metrics.cancellations.rate  \
# 0                                             0.0000
# 1                                             0.0046
# 2                                             0.0000
# 3                                             0.0000
# 4                                             0.0000
#
#    seller.seller_reputation.metrics.cancellations.value  \
# 0                                                0.0
# 1                                               18.0
# 2                                                0.0
# 3                                                0.0
# 4                                                0.0
#
#   seller.seller_reputation.metrics.cancellations.period  \
# 0                                            60 days
# 1                                            60 days
# 2                                            60 days
# 3                                            60 days
# 4                                            60 days
#
#   seller.seller_reputation.level_id     prices.id  \
# 0                           5_green  MLA901948080
# 1                           5_green  MLA869356478
# 2                           5_green  MLA851109741
# 3                           5_green  MLA836983125
# 4                           5_green  MLA899116906
#
#                                        prices.prices  \
# 0  [{'id': '19', 'type': 'standard', 'conditions'...
# 1  [{'id': '24', 'type': 'standard', 'conditions'...
# 2  [{'id': '3', 'type': 'standard', 'conditions':...
# 3  [{'id': '3', 'type': 'standard', 'conditions':...
# 4  [{'id': '2', 'type': 'standard', 'conditions':...
#
#   prices.presentation.display_currency prices.payment_method_prices  \
# 0                                  ARS                           []
# 1                                  ARS                           []
# 2                                  ARS                           []
# 3                                  ARS                           []
# 4                                  ARS                           []
#
#    installments.quantity  installments.amount  installments.rate  \
# 0                   12.0              1786.79              70.17
# 1                   12.0              1453.54              70.17
# 2                   12.0               113.30              70.17
# 3                    9.0                99.00               0.00
# 4                   12.0                92.88              70.17
#
#   installments.currency_id address.state_id address.state_name  \
# 0                      ARS             AR-B       Buenos Aires
# 1                      ARS             AR-B       Buenos Aires
# 2                      ARS             AR-S           Santa Fe
# 3                      ARS             AR-C    Capital Federal
# 4                      ARS             AR-C    Capital Federal
#
#     address.city_id     address.city_name  shipping.free_shipping  \
# 0              None  Remedios de Escalada                    True
# 1  TUxBQ0xPTWMwNjk3       Lomas de Zamora                    True
# 2              None              Santa Fe                   False
# 3  TUxBQlZJTDYzNzZa          Villa Devoto                   False
# 4  TUxBQlBBUjUyOTZa      Parque Chacabuco                    True
#
#   shipping.mode                               shipping.tags  \
# 0           me2  [self_service_in, mandatory_free_shipping]
# 1           me2                   [mandatory_free_shipping]
# 2           me2                               [fulfillment]
# 3           me2              [fulfillment, self_service_in]
# 4           me2              [fulfillment, self_service_in]
#
#   shipping.logistic_type  shipping.store_pick_up seller_address.id  \
# 0               drop_off                   False
# 1          cross_docking                    True
# 2            fulfillment                   False
# 3            fulfillment                   False
# 4            fulfillment                   False
#
#   seller_address.comment seller_address.address_line seller_address.zip_code  \
# 0
# 1
# 2
# 3
# 4
#
#   seller_address.country.id seller_address.country.name  \
# 0                        AR                   Argentina
# 1                        AR                   Argentina
# 2                        AR                   Argentina
# 3                        AR                   Argentina
# 4                        AR                   Argentina
#
#   seller_address.state.id seller_address.state.name seller_address.city.id  \
# 0                    AR-B              Buenos Aires                   None
# 1                    AR-B              Buenos Aires       TUxBQ0xPTWMwNjk3
# 2                    AR-S                  Santa Fe                   None
# 3                    AR-C           Capital Federal       TUxBQlZJTDYzNzZa
# 4                    AR-C           Capital Federal       TUxBQlBBUjUyOTZa
#
#   seller_address.city.name seller_address.latitude seller_address.longitude  \
# 0     Remedios de Escalada
# 1          Lomas de Zamora
# 2                 Santa Fe
# 3             Villa Devoto
# 4         Parque Chacabuco
#
#    differential_pricing.id  \
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3               33678187.0
# 4                      NaN
#
#    seller.seller_reputation.metrics.claims.excluded.real_rate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    seller.seller_reputation.metrics.claims.excluded.real_value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    seller.seller_reputation.metrics.delayed_handling_time.excluded.real_rate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    seller.seller_reputation.metrics.delayed_handling_time.excluded.real_value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    seller.seller_reputation.metrics.cancellations.excluded.real_rate  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    seller.seller_reputation.metrics.cancellations.excluded.real_value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   seller.seller_reputation.protection_end_date  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   seller.seller_reputation.real_level seller.car_dealer_logo  \
# 0                                 NaN                    NaN
# 1                                 NaN                    NaN
# 2                                 NaN                    NaN
# 3                                 NaN                    NaN
# 4                                 NaN                    NaN
#
#   seller.eshop.eshop_rubro.id seller.eshop.eshop_rubro.name  \
# 0                         NaN                           NaN
# 1                         NaN                           NaN
# 2                         NaN                           NaN
# 3                         NaN                           NaN
# 4                         NaN                           NaN
#
#   seller.eshop.eshop_rubro.category_id root_category_id  \
# 0                                  NaN          MLA5725
# 1                                  NaN          MLA5725
# 2                                  NaN          MLA5725
# 3                                  NaN          MLA5725
# 4                                  NaN          MLA5725
#
#           root_category_name  prices installments address.area_code  \
# 0  Accesorios para Vehículos     NaN          NaN               NaN
# 1  Accesorios para Vehículos     NaN          NaN               NaN
# 2  Accesorios para Vehículos     NaN          NaN               NaN
# 3  Accesorios para Vehículos     NaN          NaN               NaN
# 4  Accesorios para Vehículos     NaN          NaN               NaN
#
#   address.phone1 seller_contact.contact seller_contact.other_info  \
# 0            NaN                    NaN                       NaN
# 1            NaN                    NaN                       NaN
# 2            NaN                    NaN                       NaN
# 3            NaN                    NaN                       NaN
# 4            NaN                    NaN                       NaN
#
#   seller_contact.area_code seller_contact.phone seller_contact.area_code2  \
# 0                      NaN                  NaN                       NaN
# 1                      NaN                  NaN                       NaN
# 2                      NaN                  NaN                       NaN
# 3                      NaN                  NaN                       NaN
# 4                      NaN                  NaN                       NaN
#
#   seller_contact.phone2 seller_contact.email seller_contact.webpage  \
# 0                   NaN                  NaN                    NaN
# 1                   NaN                  NaN                    NaN
# 2                   NaN                  NaN                    NaN
# 3                   NaN                  NaN                    NaN
# 4                   NaN                  NaN                    NaN
#
#   location.address_line location.zip_code location.subneighborhood  \
# 0                   NaN               NaN                      NaN
# 1                   NaN               NaN                      NaN
# 2                   NaN               NaN                      NaN
# 3                   NaN               NaN                      NaN
# 4                   NaN               NaN                      NaN
#
#   location.neighborhood.id location.neighborhood.name location.city.id  \
# 0                      NaN                        NaN              NaN
# 1                      NaN                        NaN              NaN
# 2                      NaN                        NaN              NaN
# 3                      NaN                        NaN              NaN
# 4                      NaN                        NaN              NaN
#
#   location.city.name location.state.id location.state.name  \
# 0                NaN               NaN                 NaN
# 1                NaN               NaN                 NaN
# 2                NaN               NaN                 NaN
# 3                NaN               NaN                 NaN
# 4                NaN               NaN                 NaN
#
#   location.country.id location.country.name  location.latitude  \
# 0                 NaN                   NaN                NaN
# 1                 NaN                   NaN                NaN
# 2                 NaN                   NaN                NaN
# 3                 NaN                   NaN                NaN
# 4                 NaN                   NaN                NaN
#
#    location.longitude seller.home_image_url sale_terms discount  \
# 0                 NaN                   NaN        NaN      NaN
# 1                 NaN                   NaN        NaN      NaN
# 2                 NaN                   NaN        NaN      NaN
# 3                 NaN                   NaN        NaN      0.1
# 4                 NaN                   NaN        NaN      NaN
#
#                     category_name  \
# 0                        Estéreos
# 1  Neumáticos de Auto y Camioneta
# 2              Llaves Telecomando
# 3             Fundas Cubre Ruedas
# 4      Dispositivos para TelePASE
#
#                                 categories_from_root
# 0  [Accesorios para Vehículos, Audio para Vehícul...
# 1  [Accesorios para Vehículos, Neumáticos, [Estér...
# 2  [Accesorios para Vehículos, Repuestos Autos y ...
# 3  [Accesorios para Vehículos, Accesorios de Auto...
# 4  [Accesorios para Vehículos, [Estéreos, Neumáti...

# %% [markdown]
# ## Persist "raw" data

# %%
file_name = input_path + "raw_data.csv"
df.to_csv(file_name, sep='\t', encoding='utf-8', index=False)
