# %%
import json
from urllib.request import urlopen
import urllib
import pandas as pd
from tqdm.notebook import tqdm
import os
import matplotlib.pyplot as plt
import seaborn as sn

# %%
os.chdir("..")

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
display(HTML("<style>.prompt { font-size: 08px !important; }</style>"))
pd.options.display.max_columns = None
# Out:
# <style>.container { width:100% !important; }</style>
# <style>.prompt { font-size: 08px !important; }</style>

# %%
seed = 1111

# %%
data_path = "data/"

# %%
df = pd.read_csv(data_path + 'data.csv', sep='\t', encoding='utf-8', )  
df.head()
# Out:
#    installments.quantity  installments.rate            id site_id  \
# 0                   12.0              70.17  MLA901948080     MLA
# 1                   12.0              70.17  MLA869356478     MLA
# 2                   12.0              70.17  MLA862644604     MLA
# 3                   12.0              70.17  MLA836881964     MLA
# 4                   12.0              70.17  MLA851109741     MLA
#
#                                                title    price currency_id  \
# 0  Estéreo Para Auto Pioneer Mvh S215bt Con Usb Y...  12600.0         ARS
# 1    Neumático Pirelli Formula Energy 185/60 R14 82h  10250.0         ARS
# 2  Casco Para Moto Integral Halcon H57 Negro Tall...   2289.5         ARS
# 3  Compresor De Aire Alto Impacto Portátil 250 Ps...   1899.0         ARS
# 4  Carcasa Llave Navaja Peugeot  2 Bot 307 308 C/...    799.0         ARS
#
#    available_quantity  sold_quantity buying_mode listing_type_id condition  \
# 0                   1              5  buy_it_now    gold_special       new
# 1                  50            500  buy_it_now    gold_special       new
# 2                   1            250  buy_it_now    gold_special       new
# 3                 500            500  buy_it_now    gold_special       new
# 4                  50            500  buy_it_now    gold_special       new
#
#    accepts_mercadopago category_id  is_official_store catalog_product_id  \
# 0                    1     MLA6867                  0        MLA14983192
# 1                    1    MLA22195                  1        MLA15000133
# 2                    1     MLA4712                  0        MLA11386900
# 3                    1   MLA370797                  1        MLA16452983
# 4                    1   MLA373345                  0                NaN
#
#                                                 tags  catalog_listing  \
# 0  ['loyalty_discount_eligible', 'brand_verified'...                1
# 1  ['brand_verified', 'good_quality_picture', 'go...                1
# 2  ['good_quality_thumbnail', 'loyalty_discount_e...                1
# 3  ['dragged_bids_and_visits', 'good_quality_pict...                0
# 4  ['good_quality_picture', 'good_quality_thumbna...                0
#
#    seller.id  seller.car_dealer  seller.real_estate_agency  \
# 0    8911722                  0                          0
# 1  116026826                  0                          0
# 2   19876329                  0                          0
# 3  417972986                  0                          0
# 4  435859328                  0                          0
#
#                                          seller.tags  \
# 0  ['normal', 'user_info_verified', 'eshop', 'cre...
# 1  ['brand', 'user_info_verified', 'large_seller'...
# 2  ['normal', 'user_info_verified', 'credits_prio...
# 3  ['brand', 'user_info_verified', 'large_seller'...
# 4  ['normal', 'user_info_verified', 'eshop', 'msh...
#
#    seller.seller_reputation.transactions.total  \
# 0                                        410.0
# 1                                      22558.0
# 2                                     188730.0
# 3                                     364825.0
# 4                                       7334.0
#
#    seller.seller_reputation.transactions.canceled  \
# 0                                            30.0
# 1                                           973.0
# 2                                         14338.0
# 3                                         16464.0
# 4                                           386.0
#
#   seller.seller_reputation.transactions.period  \
# 0                                     historic
# 1                                     historic
# 2                                     historic
# 3                                     historic
# 4                                     historic
#
#    seller.seller_reputation.transactions.ratings.negative  \
# 0                                               0.01
# 1                                               0.01
# 2                                               0.03
# 3                                               0.03
# 4                                               0.01
#
#    seller.seller_reputation.transactions.ratings.positive  \
# 0                                               0.99
# 1                                               0.96
# 2                                               0.94
# 3                                               0.96
# 4                                               0.98
#
#    seller.seller_reputation.transactions.ratings.neutral  \
# 0                                               0.00
# 1                                               0.03
# 2                                               0.03
# 3                                               0.01
# 4                                               0.01
#
#    seller.seller_reputation.transactions.completed  \
# 0                                            380.0
# 1                                          21585.0
# 2                                         174392.0
# 3                                         348361.0
# 4                                           6948.0
#
#   seller.seller_reputation.power_seller_status  \
# 0                                       silver
# 1                                     platinum
# 2                                     platinum
# 3                                     platinum
# 4                                     platinum
#
#    seller.seller_reputation.metrics.claims.rate  \
# 0                                        0.0000
# 1                                        0.0041
# 2                                        0.0166
# 3                                        0.0067
# 4                                        0.0054
#
#    seller.seller_reputation.metrics.delayed_handling_time.rate  \
# 0                                             0.0000
# 1                                             0.0558
# 2                                             0.0643
# 3                                             0.0000
# 4                                             0.0025
#
#    seller.seller_reputation.metrics.delayed_handling_time.value  \
# 0                                                0.0
# 1                                              166.0
# 2                                             1503.0
# 3                                                0.0
# 4                                                6.0
#
#   seller.seller_reputation.metrics.delayed_handling_time.period  \
# 0                                            60 days
# 1                                            60 days
# 2                                            60 days
# 3                                            60 days
# 4                                            60 days
#
#   seller.seller_reputation.metrics.sales.period  \
# 0                                       60 days
# 1                                       60 days
# 2                                       60 days
# 3                                       60 days
# 4                                       60 days
#
#    seller.seller_reputation.metrics.sales.completed  \
# 0                                              63.0
# 1                                            3648.0
# 2                                           24591.0
# 3                                           63441.0
# 4                                            2297.0
#
#    seller.seller_reputation.metrics.cancellations.rate  \
# 0                                             0.0000
# 1                                             0.0044
# 2                                             0.0132
# 3                                             0.0009
# 4                                             0.0000
#
#    seller.seller_reputation.metrics.cancellations.value  \
# 0                                                0.0
# 1                                               17.0
# 2                                              351.0
# 3                                               62.0
# 4                                                0.0
#
#   seller.seller_reputation.metrics.cancellations.period  \
# 0                                            60 days
# 1                                            60 days
# 2                                            60 days
# 3                                            60 days
# 4                                            60 days
#
#                                        prices.prices address.state_name  \
# 0  [{'id': '17', 'type': 'standard', 'conditions'...       Buenos Aires
# 1  [{'id': '24', 'type': 'standard', 'conditions'...       Buenos Aires
# 2  [{'id': '6', 'type': 'standard', 'conditions':...    Capital Federal
# 3  [{'id': 'c98a86c0-79ec-47a5-8ea4-f605f4c0b369'...       Buenos Aires
# 4  [{'id': '3', 'type': 'standard', 'conditions':...           Santa Fe
#
#    shipping.free_shipping shipping.mode  \
# 0                       1           me2
# 1                       1           me2
# 2                       0           me2
# 3                       0           me2
# 4                       0           me2
#
#                                        shipping.tags shipping.logistic_type  \
# 0     ['self_service_in', 'mandatory_free_shipping']               drop_off
# 1                        ['mandatory_free_shipping']          cross_docking
# 2  ['self_service_in', 'fs_threshold_mla_change_f...          cross_docking
# 3  ['fulfillment', 'fs_threshold_mla_change_feb20...            fulfillment
# 4                                    ['fulfillment']            fulfillment
#
#    shipping.store_pick_up seller.seller_reputation.real_level  \
# 0                       0                                 NaN
# 1                       1                                 NaN
# 2                       0                                 NaN
# 3                       0                                 NaN
# 4                       0                                 NaN
#
#   root_category_id         root_category_name  discount  \
# 0          MLA5725  Accesorios para Vehículos       NaN
# 1          MLA5725  Accesorios para Vehículos       NaN
# 2          MLA5725  Accesorios para Vehículos  0.050000
# 3          MLA5725  Accesorios para Vehículos  0.321543
# 4          MLA5725  Accesorios para Vehículos       NaN
#
#                     category_name  \
# 0                        Estéreos
# 1  Neumáticos de Auto y Camioneta
# 2                          Cascos
# 3                Mini Compresores
# 4              Llaves Telecomando
#
#                                 categories_from_root
# 0  ['Accesorios para Vehículos', 'Audio para Vehí...
# 1  ['Accesorios para Vehículos', 'Neumáticos', 0 ...
# 2  ['Accesorios para Vehículos', 'Acc. para Motos...
# 3  ['Accesorios para Vehículos', 'Herramientas', ...
# 4  ['Accesorios para Vehículos', 'Repuestos Autos...

# %%
# df.columns.tolist()

# %% [markdown]
# ## Train vs test

# %%
train_df = df.sample(frac=0.75, random_state=seed)
train_df.shape
# Out:
# (23194, 52)

# %%
test_df = df.loc[~df.index.isin(train_df.index)]
test_df.shape
# Out:
# (7731, 52)

# %%
file_name = data_path + "train.csv"
train_df.to_csv(file_name, sep='\t', encoding='utf-8', index=False)

# %%
file_name = data_path + "test.csv"
test_df.to_csv(file_name, sep='\t', encoding='utf-8', index=False)
